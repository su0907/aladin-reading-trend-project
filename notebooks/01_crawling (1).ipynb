# %%
# Step 0: 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# 작업 디렉토리 설정
import os
project_path = '/content/drive/MyDrive/aladin-project'

# 폴더가 없으면 생성
os.makedirs(project_path, exist_ok=True)
os.makedirs(f'{project_path}/data/raw', exist_ok=True)

# %cd {project_path}
print(f"현재 작업 디렉토리: {os.getcwd()}")

# 필요 라이브러리
import re
import time, datetime, ssl
import pandas as pd
import urllib.request
from itertools import count
from bs4 import BeautifulSoup
from random import uniform

class AladinBestSeller():
    myencoding = 'utf-8'

    def getSoup(self):
        if self.soup == None:
            return None
        else:
            return BeautifulSoup(self.soup, 'html.parser')

    def get_request_url(self):
        request = urllib.request.Request(self.url)
        try:
            context = ssl._create_unverified_context()
            response = urllib.request.urlopen(request, context=context)
            if response.getcode() == 200:
                return response.read().decode(self.myencoding)
        except Exception as err:
            print(err)
            now = datetime.datetime.now()
            msg = '[%s] error for url %s' % (now, self.url)
            print(msg)
            return None

    def save2Csv(self, result):
        data = pd.DataFrame(result, columns=self.mycolumns)
        # 구글 드라이브 경로에 저장
        save_path = f'data/raw/{self.siteName}.csv'
        data.to_csv(save_path, encoding='utf-8-sig', index=True)
        print(f"✅ 파일 저장 완료: {save_path}")

    def __init__(self, siteName, url):
        self.siteName = siteName
        self.url = url
        self.mycolumns = ['year', 'month', 'rank', 'category', 'title', 'price', 'star_score', 'item_id']
        self.soup = self.get_request_url()

####################################################
siteName = 'aladin'
base_url = 'https://www.aladin.co.kr/shop/common/wbest.aspx'
####################################################

def getData():
    savedData = []
    for year in range(2020, 2026):
        last_month = 9 if year == 2025 else 12
        for month in range(1, last_month + 1):
            url = base_url
            url += '?BranchType=1&CID=0&Year=' + str(year)
            url += '&Month=' + str(month)
            url += '&Week=1&BestType=MonthlyBest&SearchSubBarcode='
            print(url)

            aladin = AladinBestSeller(siteName, url)
            soup = aladin.getSoup()

            if soup is None:
                break

            for rank, item in enumerate(soup.select("div.ss_book_box"), start=1):
                try:
                    catrgory_tag = item.select_one("span.tit_catrgory")
                    catrgory = catrgory_tag.get_text(strip=True).strip('[]') if catrgory_tag else "N/A"

                    title_tag = item.select_one("a.bo3")
                    title = title_tag.get_text(strip=True) if title_tag else "N/A"

                    item_id = "N/A"
                    if title_tag and title_tag.has_attr('href'):
                        match = re.search(r'ItemId=(\d+)', title_tag['href'])
                        if match:
                            item_id = match.group(1)

                    price_tag = item.select_one("span.ss_p2")
                    price_text = price_tag.get_text(strip=True).split('원')[0] if price_tag else "0"
                    price = int(price_text.replace(",", ""))

                    star_score_tag = item.select_one("span.star_score")
                    star_score = float(star_score_tag.get_text(strip=True)) if star_score_tag else 0.0

                    savedData.append([year, month, rank, catrgory, title, price, star_score, item_id])
                except Exception as err:
                    print(err)
                    continue

            time.sleep(uniform(1, 2))

    aladin.save2Csv(savedData)
    print('=' * 50)
    print(f"총 {len(savedData)}개 데이터 수집 완료")
    return len(savedData)

####################################################
print(siteName + ' 베스트셀러 크롤링 시작')
total_count = getData()
print(siteName + ' 베스트셀러 크롤링 끝')
print(f"data/raw/aladin.csv 파일이 구글 드라이브에 저장되었습니다.")
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/aladin-project
# 현재 작업 디렉토리: /content/drive/MyDrive/aladin-project
# aladin 베스트셀러 크롤링 시작
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=1&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=2&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=3&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=4&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=5&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=6&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=7&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=8&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=9&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=10&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=11&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2020&Month=12&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=1&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=2&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=3&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=4&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=5&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=6&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=7&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=8&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=9&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=10&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=11&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2021&Month=12&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=1&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=2&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=3&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=4&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=5&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=6&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=7&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=8&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=9&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=10&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=11&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2022&Month=12&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=1&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=2&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=3&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=4&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=5&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=6&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=7&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=8&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=9&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=10&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=11&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2023&Month=12&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=1&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=2&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=3&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=4&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=5&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=6&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=7&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=8&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=9&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=10&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=11&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=12&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=1&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=2&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=3&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=4&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=5&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=6&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=7&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=8&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2025&Month=9&Week=1&BestType=MonthlyBest&SearchSubBarcode=
# ✅ 파일 저장 완료: data/raw/aladin.csv
# ==================================================
# 총 3445개 데이터 수집 완료
# aladin 베스트셀러 크롤링 끝
# data/raw/aladin.csv 파일이 구글 드라이브에 저장되었습니다.

# %%
# Step 0: 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# 작업 디렉토리 설정
import os
project_path = '/content/drive/MyDrive/aladin-project'
# %cd {project_path}
print(f"현재 작업 디렉토리: {os.getcwd()}")

# Step 1: 라이브러리 import
import time
import datetime
import ssl
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup
import re
from random import uniform
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# Step 2: 카테고리 크롤링 클래스 정의
class AladinCategoryCrawler():
    myencoding = 'utf-8'

    def get_category_from_detail(self, detail_url, retry=3):
        """상세 페이지에서 카테고리 추출"""
        for attempt in range(retry):
            try:
                request = urllib.request.Request(detail_url)
                request.add_header('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36')
                context = ssl._create_unverified_context()
                response = urllib.request.urlopen(request, context=context, timeout=15)

                if response.getcode() == 200:
                    html = response.read().decode(self.myencoding)
                    soup = BeautifulSoup(html, 'html.parser')
                    category_links = soup.select('ul#ulCategory li a')

                    if len(category_links) >= 2:
                        return category_links[1].get_text(strip=True)
                    return "N/A"
            except Exception as err:
                if attempt < retry - 1:
                    wait_time = (attempt + 1) * 2
                    time.sleep(wait_time)
                else:
                    return "N/A"
        return "N/A"

    def save2Csv(self, result):
        data = pd.DataFrame(result, columns=self.mycolumns)
        save_path = f'data/raw/{self.siteName}.csv'
        data.to_csv(save_path, encoding='utf-8-sig', index=False)
        print(f"파일 저장 완료: {save_path}")

    def __init__(self, siteName):
        self.siteName = siteName
        self.mycolumns = ['item_id', 'real_category']

# Step 3: 카테고리 크롤링 함수
def getCategoryData(csv_file='data/raw/aladin.csv', max_workers=15):
    """기존 CSV에서 고유 ItemId의 카테고리를 병렬로 크롤링"""

    try:
        df = pd.read_csv(csv_file, index_col=0)
        if 'item_id' not in df.columns:
            print(f"오류: {csv_file}에 'item_id' 컬럼이 없습니다.")
            return
    except FileNotFoundError:
        print(f"오류: {csv_file} 파일을 찾을 수 없습니다.")
        return

    print(f"원본 데이터: {len(df)}개 행")

    # 고유 ItemId 추출
    df_valid = df[pd.to_numeric(df['item_id'], errors='coerce').notnull()]
    unique_item_ids = df_valid['item_id'].unique()

    total_count = len(unique_item_ids)
    if total_count == 0:
        print("크롤링할 유효한 item_id가 없습니다.")
        return

    print(f"고유 ItemID 수: {total_count}개")

    crawler = AladinCategoryCrawler('category_mapping')
    savedData = []

    def fetch_category(item_id):
        """단일 ItemID에 대해 카테고리를 가져오는 함수"""
        try:
            detail_url = f'https://www.aladin.co.kr/shop/wproduct.aspx?ItemId={item_id}'
            category = crawler.get_category_from_detail(detail_url)
            time.sleep(uniform(0.5, 1.5))
            return (item_id, category, None)
        except Exception as err:
            return (item_id, 'N/A', str(err))

    print(f"병렬 크롤링 시작 (최대 {max_workers}개 동시 작업)...")

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(fetch_category, item_id): item_id for item_id in unique_item_ids}

        for future in tqdm(as_completed(futures), total=total_count, desc="카테고리 크롤링"):
            item_id, category, error = future.result()
            savedData.append([item_id, category])

            if error:
                tqdm.write(f"  [오류] ItemID {item_id}: {error}")

    crawler.save2Csv(savedData)

    print("=" * 60)
    print(f"총 {len(savedData)}개 ItemID 처리 완료")
    success = len([x for x in savedData if x[1] != 'N/A'])
    print(f"카테고리 추출 성공: {success}개")
    print(f"카테고리 추출 실패: {len(savedData) - success}개")

# Step 4: 크롤링 실행
print("category_mapping 카테고리 크롤링 시작")
getCategoryData('data/raw/aladin.csv', max_workers=15)
print("category_mapping 카테고리 크롤링 끝")

# Step 5: 결과 확인
df_category = pd.read_csv('data/raw/category_mapping.csv')
print(f"\n카테고리 데이터: {len(df_category)}개 행")
df_category.head(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/aladin-project
# 현재 작업 디렉토리: /content/drive/MyDrive/aladin-project
# category_mapping 카테고리 크롤링 시작
# 원본 데이터: 3445개 행
# 고유 ItemID 수: 1909개
# 병렬 크롤링 시작 (최대 15개 동시 작업)...
# 카테고리 크롤링: 100%|██████████| 1909/1909 [07:25<00:00,  4.28it/s]
# 파일 저장 완료: data/raw/category_mapping.csv
# ============================================================
# 총 1909개 ItemID 처리 완료
# 카테고리 추출 성공: 1890개
# 카테고리 추출 실패: 19개
# category_mapping 카테고리 크롤링 끝
#
# 카테고리 데이터: 1909개 행
#      item_id real_category
# 0  227151626           NaN
# 1  223726675           에세이
# 2  221601434       소설/시/희곡
# 3     870950            과학
# 4  212657645          자기계발
# 5  193591681       소설/시/희곡
# 6  220642182          자기계발
# 7  227151653           NaN
# 8  227693700            만화
# 9  214116947           인문학
